# %%
import numpy as np
import pandas as pd
import os
import re
from tqdm import tqdm
from biopandas.pdb import PandasPdb

# %%
experimental_data_dir = 'experimental_data/FullyAnnotatedPDB_V2/'
combined_files = os.listdir(experimental_data_dir)

# %%
combined_files
# Out:
# ['DB22549.csv',
#  'DB26960.pdb',
#  'a-D-Kdop-(2-8)-a-D-Kdop-(2-4)-a-D-Kdop-(2-6)-b-D-GlcpNAc-(1-1)-Allyl.csv',
#  'repeat-2)-b-D-GlcpA-(1-3)-a-D-GalpNAc-(1-3)-a-D-GalpNAc-(1-2)-a-L-Fucp-(1-.csv',
#  'a-L-Rhap-(1-4)-a-D-GalpA-(1-3)-b-D-GlcpNAc-(1-2)-a-L-Rhap-(3-1)-a-L-Rhap.pdb',
#  'a-D-Xylp-(1-6)-b-D-Glcp-(1-4)-D-Glc-ol.csv',
#  'a-D-Glcp-(1-2)-a-D-Glcp-(1-2)-a-D-Glcp-(1-2)-a-D-Glcp-(1-2)-b-D-Fruf-(1-2)-b-D-Fruf.pdb',
#  'DB9948.csv',
#  'DB26476.csv',
#  'DB26813.csv',
#  'DB26712.csv',
#  'a-D-GalpNAc-(1-4)-a-D-Galp-(1-6)-a-D-Galp-(1-3)-a-D-Galp.csv',
#  'DB22557.csv',
#  'b-D-GlcpA-(1-4)-b-D-GlcpA-(1-3)-a-D-GalpA-(1-4)-a-D-Galp.pdb',
#  'b-D-Glcp-(1-6)-b-D-Glcp-(1-6)-b-D-GlcpNAc-(1-2)-a-D-Glcp.csv',
#  'DB26921.pdb',
#  'a-D-Rhap4NAc-(1-3)-a-D-Rhap4NAc-(1-3)-b-D-Rhap4NAc.csv',
#  'DB26709.csv',
#  'b-D-Galp-(1-2)-a-D-Glcp1OMe.csv',
#  'DB26511.pdb',
#  'a-D-Idop.csv',
#  'DB12745.pdb',
#  'b-D-Quip-(1-6)-b-D-Galp-(1-6)-b-D-GlcpNAc-(1-6)-b-D-Galp-(1-3)-b-D-GlcpNAc.pdb',
#  'a-D-Galp-(1-3)-b-D-GalpNAc-(1-6)-a-D-Glcp-(1-4)-b-D-GlcpA-(1-4)-b-D-GalpNAc.pdb',
#  'Repeat-4)-a-D-GlcpNAc-(1-4)-a-D-GlcpA-(1-3)-a-D-Galp-(1-3)-b-D-ManpNAc-(1-4)-b-D-Glcp-(1-.csv',
#  'a-D-GlcpA-(1-2)-a-D-GalpA-(1-2)-a-D-Manp.pdb',
#  'b-L-Rhap.pdb',
#  'a-D-GalpA-(1-3)-a-D-GalpA-(1-3)-b-D-GlcpNAc-(1-4)-a-D-GlcpNAc.csv',
#  'DB26907.pdb',
#  'a-D-Glcp-(1-3)-b-L-Galp.pdb',
#  'repeat-4)-b-D-Galp-(1-4)-a-D-GlcpNAc-(1-4)-b-D-Galp-(1-3)-a-D-GlcpNAc-(1-2)-b-D-Ribf-(1-.pdb',
#  'P-(O-4)-a-D-Glcp-(1-1)-a-D-Glcp.csv',
#  'Repeat-4)-a-D-GlcpA-(1-3)-a-D-Glcp-(1-3)-b-D-ManpNAc-(1-4)-b-D-Glcp-(1-4)-a-D-GlcpNAc-(1-.csv',
#  'a-D-Araf.csv',
#  'a-D-GlcpA.csv',
#  'a-L-Rhap.csv',
#  'DB26920.pdb',
#  'b-D-Glcp-(1-6)-b-D-Glcp-(1-3)-b-D-Glcp.csv',
#  'b-D-Galp-(1-3)-b-D-GlcpNAc.pdb',
#  'a-L-Rhap-(1-4)-a-D-Glcp-(1-3)-b-L-Rhap-(1-4)-b-D-Glcp-(1-4)-a-D-Glcp-(3-1)-a-L-Rhap.pdb',
#  'LFucpa1-3[DGalpb1-4]DGlcpNAcb1-3DGalpb1-4DGlc.pdb',
#  'a-D-Kdop-(2-8)-a-D-Kdop-(2-4)-a-D-Kdop-(2-6)-b-D-GlcpNAc-(1-6)-a-D-GlcpNAc-(1-1)-Allyl.pdb',
#  'DB26878.csv',
#  'a-D-Manp-(1-2)-a-D-Glcp1OMe.pdb',
#  'a-L-Rhap-(1-3)-a-L-Rhap-(1-2)-Groal.csv',
#  'a-L-Fucp-(1-2)-a-D-Manp.pdb',
#  'a-D-Kdop-(2-8)-a-D-Kdop-(2-4)-a-D-Kdop-(2-6)-b-D-GlcpNAc-(1-1)-Allyl.pdb',
#  'DB9155.csv',
#  'a-L-Rhap-(1-3)-a-D-Glcp1OMe.csv',
#  'DB26405.csv',
#  'b-D-Ribp.csv',
#  'DB22482.pdb',
#  'a-D-GlcpA-(1-2)-a-D-GalpA-(1-2)-b-D-Manp-(1-4)-b-D-Galp-(1-2)-a-D-Rhap.pdb',
#  'DB26521.csv',
#  'DB4858.csv',
#  'DB26636.pdb',
#  'a-D-Xylp-(1-6)-b-D-Glcp-(1-4)-D-Glc-ol.pdb',
#  'b-D-Fruf-(2-6)-b-D-Fruf.csv',
#  'DB22485.pdb',
#  'DB27271.csv',
#  'a-D-Glcp-(1-2)-b-D-Galp-(1-4)-a-D-GlcpNAc-(1-4)-b-D-Glcp-(1-3)-b-D-GlcpNAc.csv',
#  'b-D-Glcp-(1-4)-b-D-Glcp-(1-4)-b-D-Galp.pdb',
#  'a-D-Glcp-(1-3)-a-L-FucpNAc-(1-3)-a-D-GlcpNAc-(1-3)-a-L-FucpNAc-(1-4)-b-D-Glcp.pdb',
#  'a-D-Kdop-(2-8)-a-D-Kdop-(2-4)-a-D-Kdop-(2-6)-b-D-GlcpN4PO4-(1-6)-a-D-GlcpN1PO4.csv',
#  'a-D-Galp-(1-3)-b-D-GalpNAc-(1-6)-a-D-Glcp-(1-4)-b-D-GlcpA-(1-4)-b-D-GalpNAc.csv',
#  'a-D-GlcpNac-(1-4)-a-D-GlcpNac.pdb',
#  'a-D-Manp-(1-2)-a-D-Manp-(1-2)-b-D-Manp-(1-3)-a-D-GalpNAc.csv',
#  'repeat-4)-b-D-Galp-(1-4)-a-D-GlcpNAc-(1-4)-b-D-Galp-(1-3)-a-D-GlcpNAc-(1-2)-b-D-Ribf-(1-.csv',
#  'DB22544.pdb',
#  'a-L-Fucp-(1-2)-b-D-Manp.csv',
#  'DB26517.pdb',
#  'DB26719.csv',
#  'DB9919.pdb',
#  'DB26306.csv',
#  'DB14011.pdb',
#  'DB26370.csv',
#  'DB7424.csv',
#  'DB26521.pdb',
#  'DB26404.csv',
#  'repeat-4)-a-D-Glcp-(1-4)-a-D-GlcpA-(1-3)-a-D-Galp-(1-3)-b-D-ManpNAc-(1-4)-b-D-Glcp-(1-.pdb',
#  'DB22550.csv',
#  'b-D-Fruf-(2-6)-b-D-Fruf.pdb',
#  'DB22551.pdb',
#  'DB4853.pdb',
#  'DB12870.pdb',
#  'DB26379.csv',
#  'DB9023.csv',
#  'DB9078.pdb',
#  'b-D-Quip3Nac-(1-6)-a-D-GlcpNAc-(1-4)-b-D-GlcpA-(1-3)-a-D-GalpNAc.pdb',
#  'DB22557.pdb',
#  'DB26919.csv',
#  'Repeat-2)-a-L-Rhap-(1-3)-a-D-Galp-(1-.pdb',
#  'a-D-GalpA-(1-3)-a-D-GalpA-(1-3)-b-D-GlcpNAc-(1-4)-a-D-GlcpNAc.txt',
#  'a-L-Rhap.pdb',
#  'b-L-Fucp-(1-2)-b-L-Rhap.pdb',
#  'DB26722.pdb',
#  'b-D-Ribf.pdb',
#  'DB26928.pdb',
#  'Repeat-4)-a-D-Manp-(1-4)-a-D-GalpA-(1-3)-b-D-GlcpNAc-(1-2)-a-D-Galp-(1-3)-a-L-Rhap2Ac-(1-.csv',
#  'DB26699.pdb',
#  'DB26428.pdb',
#  'a-L-Rhap-(1-2)-a-D-Glcp1OMe.pdb',
#  'DB26694.pdb',
#  'b-D-Galf-(1-3)-b-D-GalpNAc-(1-3)-b-D-Galp-(4-1)-a-D-Glcp-(6-1)-b-D-Glcp.pdb',
#  'DB26693.pdb',
#  'b-L-Fucp-(1-2)-a-L-Rhap.csv',
#  'repeat-4)-b-D-ManpNAc-(1-4)-a-D-GlcpNAc-(1-.pdb',
#  'b-D-Glcp-(1-4)-b-D-GlcpA-(1-3)-a-D-GalpA-(1-4)-b-D-Galp.pdb',
#  'DB9213.pdb',
#  'DB26618.csv',
#  'b-D-Glcp-(1-4)-b-D-GlcpA-(1-3)-a-D-GalpA2SO3-(1-4)-b-D-Galp.csv',
#  'a-D-Glcp-(1-2)-a-D-Glcp-(1-2)-b-D-Fruf-(1-2)-b-D-Fruf-(1-2)-b-D-Fruf.pdb',
#  'Repeat-6)-a-D-Glcp-(1-3)-a-L-FucpNAc-(1-3)-b-D-GlcpNAc-(1-2)-a-L-Rhap-(1-.pdb',
#  'DB9490.csv',
#  'DB26907.csv',
#  'a-D-Glcp-(1-2)-a-D-Glcp-(1-2)-a-D-Glcp-(1-2)-b-D-Fruf-(1-2)-b-D-Fruf.csv',
#  'DB26476.pdb',
#  'DB26403.pdb',
#  'DB3758_edited.pdb',
#  'b-D-Xylp-(1-3)-a-L-Arap.pdb',
#  'a-D-Kdop-(2-4)-a-D-Kdop-(2-1)-Allyl.csv',
#  'Repeat-6)-a-D-Glcp-(1-4)-b-D-GlcpA-(1-6)-b-D-Galp-(1-4)-b-D-Galp-(1-4)-b-D-GlcpNAc-(1-.pdb',
#  'DB9949.csv',
#  'a-D-GlcpNAc.pdb',
#  'b-D-ManpNAc.pdb',
#  'a-D-Ribp.csv',
#  'Repeat-6)-a-D-Glcp-(1-4)-b-D-GlcpA-(1-6)-b-D-Galp-(1-4)-b-D-Galp-(1-4)-b-D-GlcpNAc-(1-.csv',
#  'VERSION2_a-D-Quip4N-(1-4)-a-D-GlcpA-(1-6)-a-D-GlcpNAc-(1-4)-a-L-GulpA-(1-3)-b-D-FucpNAc.csv',
#  'b-D-Galp-(3-1)-a-D-Manp.pdb',
#  'a-L-Rhap-(1-3)-a-D-Glcp1OMe.pdb',
#  'DB9539.csv',
#  'a-D-Glcp-(1-2)-a-D-Glcp-(1-2)-b-D-Fruf-(1-2)-b-D-Fruf.csv',
#  'b-D-GlcpA-(1-4)-b-D-GlcpA-(1-3)-a-D-GalpA-(1-4)-a-D-Galp.csv',
#  'a-D-Glcp-(1-2)-a-D-Glcp-(1-2)-a-D-Glcp-(1-2)-b-D-Fruf-(1-2)-b-D-Fruf.pdb',
#  'DB26938.csv',
#  'DB9213.csv',
#  'b-D-Galf-(1-3)-b-D-GalpNAc-(1-3)-b-D-Galp-(4-1)-a-D-Glcp-(6-1)-b-D-Glcp.csv',
#  'a-D-Galp-(1-6)-D-GlcpN-(1-4)-D-glcpA.pdb',
#  'a-D-Manp-(1-2)-a-D-Glcp1OMe.csv',
#  'DB26517.xlsx',
#  'DB26479.csv',
#  'DB26909.pdb',
#  'a-D-Galp-(1-6)-D-GlcpN-(1-4)-D-glcpA.csv',
#  'b-L-Fucp-(1-2)-b-L-Galp1OMe.pdb',
#  'DB3501_edited.pdb',
#  'DB26383.pdb',
#  'DB22551.csv',
#  'b-D-Xylp.csv',
#  'DB22556.pdb',
#  'DB26918.pdb',
#  'b-D-GlcpA-(1-4)-b-D-GlcpA-(1-3)-a-D-GalpA-(1-4)-b-D-Galp.pdb',
#  'DB26510.csv',
#  'Repeat-3)-b-D-Galp-(1-3)-b-D-GalpNAc-(1-4)-b-D-Galp-(1-.pdb',
#  'a-L-Rhap-(1-4)-a-D-Glcp-(1-3)-b-L-Rhap-(1-4)-b-D-Glcp-(1-4)-a-D-Glcp-(3-1)-a-L-Rhap.csv',
#  'DB26812.pdb',
#  'a-D-Manp-(1-3)-a-D-Glcp1OMe.csv',
#  'b-D-Xylp-(1-3)-L-Ara-ol.pdb',
#  'b-D-GalpANAc.pdb',
#  'a-D-Manp-(1-2)-b-D-manp-(1-3)-a-D-GlcpNAc-(1-6)-a-D-Manp.csv',
#  'a-D-Kdop-(2-4)-a-D-Kdop-(2-6)-b-D-GlcpNAc-(1-6)-b-D-GlcpNAc-(1-1)-Allyl.pdb',
#  'a-L-Fucp2SO33SO34SO3-(1-2)-a-L-Fucp3SO34SO3-(1-1)-propyl.csv',
#  'DB26397.pdb',
#  'DB26618.pdb',
#  'VERSION1_a-D-Quip4N-(1-4)-a-D-GlcpA-(1-6)-a-D-GlcpNAc-(1-4)-a-L-GulpA-(1-3)-b-D-FucpNAc.pdb',
#  'b-L-Fucp-(1-3)-b-D-Galp1OMe.pdb',
#  'a-D-Glcp-(1-2)-a-D-Glcp-(1-2)-b-D-Fruf-(1-2)-b-D-Fruf-(1-2)-b-D-Fruf.csv',
#  'b-D-GlcpA-(1-4)-b-D-GlcpA-(1-3)-a-D-GalpA-(1-4)-b-D-Galp.csv',
#  'b-D-Galp-(1-3)-a-D-Glcp1OMe.pdb',
#  'b-L-Fucp-(1-2)-b-L-Galp1OMe.csv',
#  'b-D-GlcpNAc-(1-3)-b-D-Galp-(1-3)-b-D-GalpNAc-(1-3)-a-D-Galp.pdb',
#  'a-D-Rhap4NAc-(1-3)-b-D-Rhap4NAc.pdb',
#  'a-D-Kdop-(2-4)-a-D-Kdop-(2-1)-Allyl.pdb',
#  'a-D-GlcpA-(1-2)-a-D-GalpA-(1-2)-a-D-Manp.csv',
#  'a-D-GlcpNac-(1-4)-a-D-GlcpNac.csv',
#  'VERSION2_a-D-Quip4N-(1-4)-a-D-GlcpA-(1-6)-a-D-GlcpNAc-(1-4)-a-L-GulpA-(1-3)-b-D-FucpNAc - Copy.pdb',
#  'a-D-Glcp-(1-3)-b-L-Galp.csv',
#  'b-D-Apif.csv',
#  'b-L-Rhap.csv',
#  'DB26475.csv',
#  'DB26723.csv',
#  'b-L-Fucp-(1-2)-b-D-Manp.pdb',
#  'DB9188.pdb',
#  'a-L-Rhap-(1-3)-a-L-Rhap-(1-2)-Groal.pdb',
#  'DB12634.csv',
#  'DB9917.pdb',
#  'a-D-Glcp.pdb',
#  'DB4762.pdb',
#  'DB8939.csv',
#  'DB27272.csv',
#  'b-D-Galp.pdb',
#  'DB26910.pdb',
#  'DB26722.csv',
#  'Repeat-4)-b-D-GlcpA-(1-6)-a-D-Glcp-(1-4)-b-D-Galp-(1-4)-b-D-Glcp-(1-.csv',
#  'b-D-GalpANAc.csv',
#  'DB27248.pdb',
#  'DB26691.pdb',
#  'a-D-Kdop-(2-8)-a-D-Kdop-(2-4)-a-D-Kdop-(2-6)-b-D-GlcpN-(1-6)-a-D-GlcpN1PO4.csv',
#  'DB22553.csv',
#  'Repeat-2)-a-L-Rhap-(1-3)-a-D-Galp-(1-.csv',
#  'b-L-Fucp-(1-2)-a-D-Manp.pdb',
#  'DB26431.csv',
#  'DB22507.pdb',
#  'a-D-Lyxp.pdb',
#  'DB26716.csv',
#  'a-L-Rhap-(1-2)-a-L-Rhap-(1-3)-a-L-Rhap-(1-3)-b-D-GlcpNAc.csv',
#  'a-D-Glcp-(1-4)-b-D-ManpA1NAc3NAc.pdb',
#  'DB27272.pdb',
#  'b-L-Fucp.pdb',
#  'a-D-Kdop-(2-4)-a-D-Kdop-(2-6)-b-D-GlcpNAc-(1-1)-Allyl.pdb',
#  'DB26552.pdb',
#  'DB26908.pdb',
#  'DB26654.csv',
#  'DB26715.csv',
#  'DB12744.csv',
#  'DB26378.csv',
#  'a-D-Rhap4NAc-(1-3)-b-D-Rhap4NAc.csv',
#  'Repeat-3)-b-D-GlcpA-(1-3)-a-L-Rhap-(1-.csv',
#  'b-D-Xylp-(1-3)-L-Ara-ol.csv',
#  'b-D-Galp-(1-3)-b-D-Glcp-(1-3)-b-D-Xylp-(1-4)-b-D-Xylp-(1-4)-a-L-Galp-(2-1)-b-D-Xylp.csv',
#  'b-D-Galp-(1-2)-b-D-Glc1OMe.csv',
#  'DB26959.pdb',
#  'b-D-GlcpNAc.pdb',
#  'b-D-Araf.csv',
#  'DB26963.pdb',
#  'b-D-GlcpNAc-(1-3)-b-D-Galp.pdb',
#  'DB26994.csv',
#  'DB26517.csv',
#  'DB22550.pdb',
#  'DB26553.csv',
#  'a-L-Rhap-(1-3)-b-D-GlcpNAc.csv',
#  'b-D-Kdop-(2-3)-b-D-Galp-(1-4)-a-D-Galp-(1-3)-b-D-Galp.csv',
#  'a-D-GalpNAc-(1-4)-a-D-Galp-(1-6)-a-D-Galp-(1-3)-b-D-Galp.pdb',
#  'a-D-Kdop-(2-6)-b-D-GlcpNAc-(1-1)-Allyl.csv',
#  'a-D-Glcp-(1-3)-a-L-Galp.pdb',
#  'DB22547.pdb',
#  'b-D-GlcpA.csv',
#  'Galb3(Fuca4)GlcNAcb.csv',
#  'DB12634.pdb',
#  'repeat-4)-a-D-Glcp-(1-4)-a-D-GlcpA-(1-3)-a-D-Galp-(1-3)-b-D-ManpNAc-(1-4)-b-D-Glcp-(1-.csv',
#  'DB12745.csv',
#  'a-L-Fucp.csv',
#  'DB26428.csv',
#  'b-D-Glcp-(1-4)-b-D-GlcpA-(1-3)-a-D-GalpA2SO3-(1-4)-a-D-Galp.csv',
#  'a-L-Rhap-(1-4)-a-D-GalpA-(1-3)-b-D-GlcpNAc-(1-2)-a-L-Rhap-(3-1)-a-L-Rhap.csv',
#  'DB22556.csv',
#  'b-D-Glcp-(1-4)-b-D-Glcp-(1-4)-b-D-Galp.csv',
#  'a-D-GalpA-(1-3)-a-D-GalpA-(1-3)-b-D-GlcpNAc-(1-4)-a-D-GlcpNAc.pdb',
#  'b-D-GlcpNAc-(1-4)-a-D-GlcpNAc.pdb',
#  'DB3501.csv',
#  'b-D-Glcp.csv',
#  'DB26918.csv',
#  'DB22507.csv',
#  'a-L-Fucp-(1-2)-b-D-Galp-(1-3)-D-GalNAc-ol.csv',
#  'DB26712.pdb',
#  'a-D-Xylp.pdb',
#  'a-D-Kdop-(2-8)-a-D-Kdop-(2-1)-Allyl.pdb',
#  'DB26724.pdb',
#  'a-D-GalpA.csv',
#  'b-L-Fucp-(1-3)-a-D-Glcp1OMe.pdb',
#  'a-D-GalpNAc-(1-6)-a-D-Galp-(1-6)-a-D-Galp-(1-3)-D-Gal-Ol.csv',
#  'DB26682.csv',
#  'b-D-GalpA.csv',
#  'DB17331.csv',
#  'DB26720.pdb',
#  'DB26705.pdb',
#  'DB26810.csv',
#  'DB9539.pdb',
#  'DB26380.pdb',
#  'DB26991.csv',
#  'b-D-Xylp-(1-4)-b-D-Xylp-(1-4)-a-L-Galp-(2-1)-b-D-Xylp.csv',
#  'a-D-Manp-(1-2)-b-D-Glcp1OMe.csv',
#  'b-D-GlcpA-(1-2)-a-L-Rhap-(1-2)-a-L-Rhap-(1-2)-a-L-Rhap-(1-3)-b-D-Galp-(1-2)-a-L-Rhap.csv',
#  'DB13039.pdb',
#  'DB22506.pdb',
#  'DB26945.pdb',
#  'a-D-Kdop-(2-4)-a-D-Kdop-(2-6)-b-D-GlcpNAc-(1-1)-Allyl.csv',
#  'b-D-Xylp-(1-3)-b-L-Arap.pdb',
#  'a-D-GlcpNAc.csv',
#  'DB26922.csv',
#  'DB26380.csv',
#  'a-L-Fucp2SO34SO3-(1-4)-a-L-Fucp2SO3.pdb',
#  'VERSION1_a-D-Quip4N-(1-4)-a-D-GlcpA-(1-6)-a-D-GlcpNAc-(1-4)-a-L-GulpA-(1-3)-b-D-FucpNAc.csv',
#  'a-D-Glcp-(1-2)-a-D-Glcp-(1-2)-a-D-Glcp-(1-2)-a-D-Glcp-(1-2)-b-D-Fruf-(1-2)-b-D-Fruf.csv',
#  'Gala1-3(Fuca1-2)Galb.csv',
#  'b-D-Manp.pdb',
#  'DB9708.pdb',
#  'b-D-Glcp-(1-6)-b-D-Glcp-(1-3)-b-D-Glcp.pdb',
#  'a-D-Manp-(1-2)-a-D-Manp-(1-3)-Ser.pdb',
#  'DB26720.csv',
#  'a-D-Glcp-(1-3)-a-L-FucpNAc-(1-3)-a-D-GlcpNAc-(1-3)-a-L-FucpNAc-(1-4)-a-D-Glcp.pdb',
#  'a-D-Galp-(1-6)-a-D-Galp-(1-3)-D-Gal-Ol.csv',
#  'b-D-Apif.pdb',
#  'P-(O-2)-a-D-Glcp-(1-1)-a-D-Glcp.pdb',
#  'DB26636.csv',
#  'b-D-Glcp-(1-4)-b-D-GlcpA-(1-3)-a-D-GalpA-(1-4)-a-D-Galp.pdb',
#  'DB26718.csv',
#  'DB27042.pdb',
#  'a-D-Kdop-(2-8)-a-D-Kdop-(2-4)-a-D-Kdop-(2-6)-b-D-GlcpNAc-(1-6)-b-D-GlcpNAc-(1-1)-Allyl.pdb',
#  'DB13039.csv',
#  'b-L-Fucp-(1-2)-b-D-Manp.csv',
#  'a-D-Kdop-(2-8)-a-D-Kdop-(2-4)-a-D-Kdop-(2-6)-b-D-GlcpNAc-(1-6)-a-D-GlcpNAc-(1-1)-Allyl.csv',
#  'Repeat-3)-a-D-Rhap-(1-3)-a-D-Rhap-(1-4)-a-D-GalpNAc-(1-.pdb',
#  'DB9507.pdb',
#  'b-D-GlcpNAc.csv',
#  'DB7424.pdb',
#  'DB26370.pdb',
#  'repeat-2)-b-D-GlcpA-(1-3)-a-D-GalpNAc-(1-3)-a-D-GalpNAc-(1-2)-a-L-Fucp-(1-.pdb',
#  'DB26378.pdb',
#  'b-D-Xylp-(1-4)-b-D-Xylp-(1-4)-b-L-Galp-(2-1)-b-D-Xylp.csv',
#  'a-D-Kdop-(2-8)-a-D-Kdop-(2-4)-a-D-Kdop-(2-6)-b-D-GlcpNAc-(1-6)-b-D-GlcpNAc-(1-1)-Allyl.csv',
#  'a-D-Kdop-(2-6)-b-D-GlcpNAc-(1-6)-b-D-GlcpNAc-(1-1)-Allyl.pdb',
#  'b-D-Manp-(1-2)-b-D-Manp-(1-2)-b-D-Manp-(1-2)-b-D-Manp.csv',
#  'b-D-Xylp-(1-4)-b-D-Xylp-(1-4)-b-L-Galp-(2-1)-b-D-Xylp.pdb',
#  'b-D-Glcp-(1-4)-b-D-GlcpA-(1-3)-a-D-GalpA-(1-4)-b-D-Galp.csv',
#  'DB26397.csv',
#  'a-D-Glcp-(1-6)-a-D-Glcp.pdb',
#  'DB26700.csv',
#  'DB9188.csv',
#  'b-D-Galp-(1-2)-b-D-Glc1OMe.pdb',
#  'DB3758.csv',
#  'DB9948.pdb',
#  'P-(O-2)-a-D-Glcp-(1-1)-a-D-Glcp.csv',
#  'b-L-Fucp.csv',
#  'a-D-Kdop-(2-4)-a-D-Kdop-(2-6)-b-D-GlcpNAc-(1-6)-b-D-GlcpNAc-(1-1)-Allyl.csv',
#  'a-D-FucpNAc-(1-4)-a-D-GalpNac-(1-3)-b-D-Manp-(1-2)-erythritol.csv',
#  'a-D-Kdop-(2-8)-a-D-Kdop-(2-4)-a-D-Kdop-(2-6)-b-D-GlcpN4PO4-(1-6)-a-D-GlcpN1PO4.pdb',
#  'P-(O-4)-a-D-Glcp-(1-1)-a-D-Glcp.pdb',
#  'a-D-GalpA.pdb',
#  'Repeat-6)-a-D-Glcp-(1-2)-a-D-Galp-(1-6)-a-D-Galp-(1-.csv',
#  'DB27271.pdb',
#  'a-D-ManpA.pdb',
#  'b-D-Galp-(1-3)-b-D-Glcp1OMe.csv',
#  'a-D-Kdop-(2-8)-a-D-Kdop-(2-1)-Allyl.csv',
#  'repeat-4)-a-D-GalpA-(1-3)-a-D-Manp-(1-4)-b-D-Glcp-(1-3)-a-D-GlcpNAc-(1-2)-b-D-Manp-(1-3)-b-D-ManpNAc-(1-.csv',
#  'a-L-Fucp-(1-2)-b-D-Galp1OMe.pdb',
#  'Repeat-4)-a-L-IdopA-(1-4)-a-D-GlcpNAc-(1-.csv',
#  'b-D-Lyxp.csv',
#  'b-D-Galp-(1-3)-b-D-Glcp-(1-3)-b-D-Xylp-(1-4)-b-D-Xylp-(1-4)-b-L-Galp-(2-1)-b-D-Xylp.pdb',
#  'a-D-Lyxp.csv',
#  'DB9697.pdb',
#  'a-D-Kdop-(2-4)-a-D-Kdop-(2-6)-b-D-GlcpNAc-(1-6)-a-D-GlcpNAc-(1-1)-Allyl.pdb',
#  'DB26723.pdb',
#  'P-(O-3)-a-D-Glcp-(1-1)-a-D-Glcp.pdb',
#  'b-D-Glcp-(1-4)-b-D-Glcp.csv',
#  'a-L-Fucp2SO34SO3-(1-4)-a-L-Fucp2SO3.csv',
#  'a-D-Galp-(1-2)-a-L-Rhap-(1-3)-b-D-Manp-(1-4)-b-D-Manp-(1-4)-a-D-Galp-(1-3)-b-D-Galp-(2-1)-a-D-Glcp.csv',
#  'b-L-Fucp-(1-2)-a-L-Rhap.pdb',
#  'a-D-Ribp.pdb',
#  'DB26699.csv',
#  'a-D-Glcp-(1-2)-a-D-Glcp-(1-2)-b-D-Fruf-(1-2)-b-D-Fruf.pdb',
#  'b-D-Galp-(1-3)-a-D-Glcp1OMe.csv',
#  'a-D-Glcp-(1-2)-a-D-Glcp-(1-2)-a-D-Glcp-(1-2)-b-D-Fruf-(1-2)-b-D-Fruf-(1-2)-b-D-Fruf.pdb',
#  'b-D-Galp-(1-3)-a-D-GalpNAc.pdb',
#  'a-L-Rhap-(1-3)-b-D-Glcp1OMe.pdb',
#  'a-L-Fucp-(1-2)-b-D-Galp.csv',
#  'a-D-GalpNAc.pdb',
#  'b-D-GlcpA-(1-2)-a-L-Rhap-(1-2)-a-L-Rhap-(1-2)-a-L-Rhap-(1-3)-b-D-Galp-(1-2)-a-L-Rhap.pdb',
#  'a-L-Fucp-(1-2)-b-D-Glcp1OMe.csv',
#  'a-D-GalpNAc.csv',
#  'DB26467.csv',
#  'b-D-Ribp.pdb',
#  'DB26404.pdb',
#  'Repeat-3)-a-L-Rhap-(1-2)-a-L-Rhap-(1-4)-a-D-GlcpA-(1-2)-a-D-Manp-(1-2)-a-D-Manp-(1-3)-a-D-Galp-(1-.csv',
#  'DB26992.csv',
#  'DB22484.pdb',
#  'a-D-Manp-(1-2)-b-D-manp-(1-3)-a-D-GlcpNAc-(1-6)-a-D-Manp.pdb',
#  'Repeat-3)-b-D-Galp-(1-3)-b-D-GalpNAc-(1-4)-b-D-Galp-(1-.csv',
#  'b-D-Ribf-(1-4)-b-D-Galp-(1-3)-a-D-GlcpNac-(1-4)-a-D-GalpA.pdb',
#  'DB26928.csv',
#  'b-L-Fucp-(1-3)-b-D-Galp1OMe.csv',
#  'a-D-Glcp-(1-3)-a-L-Galp.csv',
#  'DB22484.csv',
#  'DB9949.pdb',
#  'b-D-GlcpNAc-(1-3)-b-D-Galp-(1-3)-b-D-GalpNAc-(1-3)-a-D-Galp.csv',
#  'b-D-Xylp-(1-3)-a-L-Arap.csv',
#  'DB22482.csv',
#  'a-D-Galp.pdb',
#  'b-L-Rhap-(1-2)-b-L-Rhap.csv',
#  'a-D-Glcp-(1-2)-a-D-Glcp-(1-2)-a-D-Glcp-(1-2)-b-D-Fruf-(1-2)-b-D-Fruf-(1-2)-b-D-Fruf.csv',
#  'a-D-Apif.csv',
#  'a-L-Rhap-(1-3)-b-D-Glcp.csv',
#  'DB26700.pdb',
#  'a-D-ManpNAc.csv',
#  'DB3758.pdb',
#  'b-L-Fucp-(1-2)-b-D-Glcp1OMe.pdb',
#  'a-L-Rhap-(1-2)-b-D-Glcp1OMe.pdb',
#  'b-D-Galp.csv',
#  'Galb3(Fuca4)GlcNAcb.pdb',
#  'a-L-Rhap-(1-3)-b-D-Galp-(1-4)-b-D-GalpNAc-(3-1)-b-D-Galp.pdb',
#  'b-D-GlcpNAc-(1-2)-b-D-GalpA-(1-3)-a-D-GalpNAc-(1-4)-a-D-GalpA.csv',
#  'Repeat-6)-a-D-Glcp-(1-4)-b-D-GlcpA-(1-4)-b-D-GalpNAc3Ac-(1-3)-a-D-Galp-(1-3)-b-D-GalpNAc-(1-.csv',
#  'DB26957.pdb',
#  'a-L-Fucp-(1-2)-b-D-Galp1OMe.csv',
#  'b-L-Rhap-(1-2)-b-L-Rhap.pdb',
#  'DB26961.csv',
#  'b-D-Glcp-(1-4)-b-D-Glcp-(1-4)-a-D-Galp.csv',
#  'DB27099.pdb',
#  'DB26874.csv',
#  'DB26960.csv',
#  'Repeat-3)-b-D-GlcpA-(1-3)-a-L-Rhap-(1-.pdb',
#  'a-D-Araf.pdb',
#  'a-L-Fucp-(1-2)-b-D-Galp-(1-3)-D-GalNAc-ol.pdb',
#  'DB26874.pdb',
#  'DB9023.pdb',
#  'DB12731.pdb',
#  'b-D-GlcpNAc-(1-4)-a-D-GlcpNAc.csv',
#  'DB26945.csv',
#  'DB26921.csv',
#  'DB26708.csv',
#  'a-D-GlcpNAc-(1-4)-b-D-Galp-(1-3)-D-GalNAc-ol.csv',
#  'DB26475.pdb',
#  'b-D-Araf.pdb',
#  'Repeat-6)-b-D-Galf-(1-5)-b-D-Galf-(1-5)-b-D-Galf-(1-5)-b-D-Galf-(1-.pdb',
#  'b-D-Manp.csv',
#  'DB26302.pdb',
#  'Repeat-6)-b-D-Galf-(1-5)-b-D-Galf-(1-5)-b-D-Galf-(1-5)-b-D-Galf-(1-.csv',
#  'b-D-Ribf.csv',
#  'a-D-Glcp-(1-3)-a-L-FucpNAc-(1-3)-a-D-GlcpNAc-(1-3)-a-L-FucpNAc-(1-4)-a-D-Glcp.csv',
#  'a-D-Galp-(1-6)-a-D-Galp-(1-3)-ononitol.pdb',
#  'b-L-Fucp-(1-2)-a-D-Manp.csv',
#  'a-D-Galp-(1-6)-a-D-Galp-(1-3)-D-Gal-Ol.pdb',
#  'a-D-ManpNAc.pdb',
#  'DB26510.pdb',
#  'b-D-Manp-(1-2)-b-D-Manp-(1-2)-b-D-Manp-(1-2)-b-D-Manp.pdb',
#  'DB22505.pdb',
#  'a-L-Fucp-(1-3)-b-D-Glcp1OMe.pdb',
#  'DB14011.csv',
#  'DB22553.pdb',
#  'DB4717.csv',
#  'b-D-GlcpNAc-(1-3)-b-D-Galp.csv',
#  'a-D-Galp-(1-2)-a-L-Rhap-(1-3)-b-D-Manp-(1-4)-b-D-Manp-(1-4)-a-D-Galp-(1-3)-b-D-Galp-(2-1)-a-D-Glcp.pdb',
#  'a-D-GlcpNAc-(1-4)-a-D-GlcpNAc-(1-4)-a-D-Kdop.pdb',
#  'DB26993.csv',
#  'DB26709.pdb',
#  'a-L-Fucp-(1-2)-b-D-Glcp1OMe.pdb',
#  'b-D-Glcp-(1-4)-b-D-GlcpA-(1-3)-a-D-GalpA2SO3-(1-4)-a-D-Galp.pdb',
#  'a-L-Fucp.pdb',
#  'b-D-Glcp-(1-4)-b-D-GlcpA-(1-3)-a-D-GalpA-(1-4)-a-D-Galp.csv',
#  'b-D-Galp-(3-1)-a-D-Manp.csv',
#  'b-L-Fucp-(1-3)-b-D-Glcp1OMe.pdb',
#  'DB26479.pdb',
#  'DB9697.csv',
#  'DB9708.csv',
#  'b-D-GlcpNAc-(1-6)-b-D-Galp-(1-3)-a-D-GalpNac.csv',
#  'b-D-Glcp-(1-4)-a-D-Glcp.pdb',
#  'b-D-Glcp.pdb',
#  'DB26959.csv',
#  'DB26502.csv',
#  'a-D-Glcp-(1-4)-b-D-ManpA1NAc3NAc.csv',
#  'Repeat-6)-a-D-Glcp-(1-2)-a-D-Galp-(1-6)-a-D-Galp-(1-.pdb',
#  'a-D-ManpA.csv',
#  'a-D-GlcpNAc-(1-4)-b-D-Galp-(1-3)-D-GalNAc-ol.pdb',
#  'DB22547.csv',
#  'a-L-Rhap-(1-2)-a-D-Glcp1OMe.csv',
#  'a-D-Kdop-(2-6)-b-D-GlcpNAc-(1-6)-b-D-GlcpNAc-(1-1)-Allyl.csv',
#  'b-L-Fucp-(1-2)-a-D-Glcp1OMe.pdb',
#  'a-L-Fucp-(1-2)-a-D-Manp.csv',
#  'DB4717.pdb',
#  'b-L-Fucp-(1-3)-a-D-Glcp1OMe.csv',
#  'b-D-Glcp-(1-6)-b-D-Glcp-(1-6)-b-D-GlcpNAc-(1-2)-a-D-Glcp.pdb',
#  'b-L-Fucp-(1-2)-a-D-Glcp1OMe.csv',
#  'DB27042.csv',
#  'DB26708.pdb',
#  'a-D-Kdop-(2-6)-b-D-GlcpNAc-(1-6)-a-D-GlcpNAc-(1-1)-Allyl.pdb',
#  'DB27270.csv',
#  'a-L-Rhap-(1-3)-b-D-Glcp.pdb',
#  'a-D-Kdop-(2-6)-b-D-GlcpNAc-(1-6)-a-D-GlcpNAc-(1-1)-Allyl.csv',
#  'a-D-Glcp-(1-3)-a-L-FucpNAc-(1-3)-a-D-GlcpNAc-(1-3)-a-L-FucpNAc-(1-4)-b-D-Glcp.csv',
#  'repeat-4)-b-D-ManpNAc-(1-4)-a-D-GlcpNAc-(1-.csv',
#  'a-D-GalpNAc-(1-4)-a-D-Galp-(1-6)-a-D-Galp-(1-3)-b-D-Galp.csv',
#  'b-D-GlcpA-(1-4)-b-D-GlcpA-(1-3)-a-D-GalpASo3-(1-4)-b-D-Galp.csv',
#  'DB22552.csv',
#  'P-(O-3)-a-D-Glcp-(1-1)-a-D-Glcp.csv',
#  'Repeat-6)-a-D-Glcp-(1-3)-a-L-Rhap2Ac-(1-3)-a-D-GlcpNAc-(1-2)-b-D-Galf-(1-.pdb',
#  'Repeat-6)-a-D-Glcp-(1-3)-a-L-Rhap2Ac-(1-3)-a-D-GlcpNAc-(1-2)-b-D-Galf-(1-.csv',
#  'DB26553.pdb',
#  'DB26724.csv',
#  'DB26302.csv',
#  'Repeat-4)-a-L-IdopA-(1-4)-a-D-GlcpNAc-(1-.pdb',
#  'b-D-Galp-(1-2)-a-D-Glcp1OMe.pdb',
#  'a-D-GlcpA.pdb',
#  'a-D-FucpNAc-(1-4)-a-D-GalpNac-(1-3)-b-D-Manp-(1-2)-erythritol.pdb',
#  'DB26908.csv',
#  'a-D-Glcp.csv',
#  'DB26511.csv',
#  'DB4853.csv',
#  'a-D-Glcp-(1-2)-b-D-Glcp-(1-3)-b-D-GlcpNAc-(1-3)-b-D-Glcp.pdb',
#  'DB9490.pdb',
#  'DB9917.csv',
#  'a-L-Fucp-(1-2)-a-D-Glcp1OMe.csv',
#  'DB26552.csv',
#  'DB27097.pdb',
#  'DB4858.pdb',
#  'DB4762.csv',
#  'DB26707.pdb',
#  'b-L-Fucp-(1-2)-b-D-Glcp1OMe.csv',
#  'DB26957.csv',
#  'NeuAca2-3Galb1-3( NeuAca2-3Galb1-4GlcNAc b1-6)GalNAc.pdb',
#  'DB26718.pdb',
#  'a-L-Rhap-(1-2)-a-L-Rhap-(1-3)-a-L-Rhap-(1-3)-b-D-GlcpNAc.pdb',
#  'b-D-Galp-(1-3)-b-D-Glcp1OMe.pdb',
#  'DB9507.csv',
#  'DB26919.pdb',
#  'DB27097.csv',
#  'Repeat-3)-a-L-Rhap-(1-2)-a-L-Rhap-(1-4)-a-D-GlcpA-(1-2)-a-D-Manp-(1-2)-a-D-Manp-(1-3)-a-D-Galp-(1-.pdb',
#  'b-D-GlcpNAc-(1-4)-b-D-GlcpNAc.csv',
#  'DB9078.csv',
#  'a-D-Manp-(1-3)-b-D-Glcp1OMe.pdb',
#  'a-D-GlcpA-(1-2)-a-D-GalpA-(1-2)-b-D-Manp-(1-4)-b-D-Galp-(1-2)-a-D-Rhap.csv',
#  'b-D-GlcpA-(1-4)-b-D-GlcpA-(1-3)-a-D-GalpASo3-(1-4)-b-D-Galp.pdb',
#  'DB26812.csv',
#  'DB26431.pdb',
#  'b-D-Quip3Nac-(1-6)-a-D-GlcpNAc-(1-4)-b-D-GlcpA-(1-3)-a-D-GalpNAc.csv',
#  'DB26878.pdb',
#  'DB26719.pdb',
#  'Repeat-6)-a-D-Glcp-(1-3)-a-L-FucpNAc-(1-3)-b-D-GlcpNAc-(1-2)-a-L-Rhap-(1-.csv',
#  'a-D-Apif.pdb',
#  'DB26922.pdb',
#  'a-D-Kdop-(2-8)-a-D-Kdop-(2-4)-a-D-Kdop-(2-6)-b-D-GlcpN-(1-6)-a-D-GlcpN1PO4.pdb',
#  'a-D-Quip4N-(1-4)-a-D-GlcpA-(1-6)-a-D-GlcpNAc-(1-4)-a-L-GulpA-(1-3)-a-D-FucpNAc.pdb',
#  'b-D-Idop.csv',
#  'DB26550.pdb',
#  'b-D-Glcp-(1-4)-a-D-Glcp.csv',
#  'a-D-GlcpA-(1-2)-a-D-GalpA-(1-2)-b-D-Manp-(1-4)-b-D-Galp-(1-2)-b-D-Rhap.csv',
#  'DB26938.pdb',
#  'DB26879.pdb',
#  'a-D-GalpNAc-(1-6)-a-D-Galp-(1-6)-a-D-Galp-(1-3)-D-Gal-Ol.pdb',
#  'NeuAca2-3Galb1-3( NeuAca2-3Galb1-4GlcNAc b1-6)GalNAc.csv',
#  'DB26810.pdb',
#  'b-L-Fucp-(1-2)-b-L-Rhap.csv',
#  'Repeat-3)-a-D-Rhap-(1-3)-a-D-Rhap-(1-4)-a-D-GalpNAc-(1-.csv',
#  'P-(O-6)-a-D-Glcp-(1-1)-a-D-Glcp.csv',
#  'DB17331.pdb',
#  'b-D-Lyxp.pdb',
#  'a-D-GalpNAc-(1-4)-a-D-Galp-(1-6)-a-D-Galp-(1-3)-a-D-Galp.pdb',
#  'DB26705.csv',
#  'a-L-Fucp-(1-2)-a-D-Galp.pdb',
#  'a-D-Manp-(1-3)-b-D-Glcp1OMe.csv',
#  'Gala1-3(Fuca1-2)Galb.pdb',
#  'DB22529.csv',
#  'DB26909.csv',
#  'a-D-GlcpNAc-(1-4)-a-D-GlcpNAc-(1-4)-a-D-Kdop.csv',
#  'DB12744.pdb',
#  'DB12870.csv',
#  'a-D-Manp-(1-3)-a-D-Glcp1OMe.pdb',
#  'DB22549.pdb',
#  'a-D-Manp-(1-2)-a-D-Manp-(1-2)-b-D-Manp-(1-3)-a-D-GalpNAc.pdb',
#  'DB22506.csv',
#  'DB26963.csv',
#  'a-L-Fucp2SO33SO34SO3-(1-2)-a-L-Fucp3SO34SO3-(1-1)-propyl.pdb',
#  'a-D-Ribf.pdb',
#  'DB26654.pdb',
#  'a-L-Fucp-(1-2)-b-D-Galp.pdb',
#  'DB26920.csv',
#  'a-D-GlcpNAc-(1-4)-b-D-GlcpNAc.csv',
#  'LFucpa1-3[DGalpb1-4]DGlcpNAcb1-3DGalpb1-4DGlc.csv',
#  'b-D-GlcpNAc-(1-6)-b-D-Galp-(1-3)-a-D-GalpNac.pdb',
#  'a-D-Rhap4NAc-(1-3)-a-D-Rhap4NAc-(1-3)-b-D-Rhap4NAc.pdb',
#  'a-D-Galp-(1-6)-a-D-Galp-(1-3)-ononitol.csv',
#  'a-D-GlcpNAc-(1-4)-b-D-GlcpNAc.pdb',
#  'repeat-4)-a-D-GalpA-(1-3)-a-D-Manp-(1-4)-b-D-Glcp-(1-3)-a-D-GlcpNAc-(1-2)-b-D-Manp-(1-3)-b-D-ManpNAc-(1-.pdb',
#  'DB26707.csv',
#  'DB12731.csv',
#  'b-D-Idop.pdb',
#  'a-D-Glcp-(1-6)-a-D-Glcp.csv',
#  'b-D-GlcpA.pdb',
#  'DB26467.pdb',
#  'a-L-Rhap-(1-2)-b-D-Glcp1OMe.csv',
#  'a-d-manp.csv',
#  'a-D-Xylp.csv',
#  'a-D-GlcpA-(1-2)-a-D-GalpA-(1-2)-b-D-Manp-(1-4)-b-D-Galp-(1-2)-b-D-Rhap.pdb',
#  'DB26306.pdb',
#  'a-D-Ribf.csv',
#  'a-D-Galp.csv',
#  'b-D-Quip-(1-6)-b-D-Galp-(1-6)-b-D-GlcpNAc-(1-6)-b-D-Galp-(1-3)-b-D-GlcpNAc.csv',
#  'DB27248.csv',
#  'DB22505.csv',
#  'DB26550.csv',
#  'DB26682.pdb',
#  'DB26692.pdb',
#  'P-(O-6)-a-D-Glcp-(1-1)-a-D-Glcp.pdb',
#  'a-D-Kdop-(2-4)-a-D-Kdop-(2-6)-b-D-GlcpNAc-(1-6)-a-D-GlcpNAc-(1-1)-Allyl.csv',
#  'DB3501_uncorrectedH6_SR.pdb',
#  'a-D-Manp-(1-2)-a-D-Manp-(1-3)-Ser.csv',
#  'b-D-Galp-(1-3)-a-D-GalpNAc.csv',
#  'b-D-Glcp-(1-4)-b-D-Glcp-(1-4)-a-D-Galp.pdb',
#  'a-L-Fucp-(1-2)-a-D-Glcp1OMe.pdb',
#  'a-D-Kdop-(2-6)-b-D-GlcpNAc-(1-1)-Allyl.pdb',
#  'a-D-Glcp-(1-2)-b-D-Glcp-(1-3)-b-D-GlcpNAc-(1-3)-b-D-Glcp.csv',
#  'b-D-Xylp-(1-4)-b-D-Xylp-(1-4)-a-L-Galp-(2-1)-b-D-Xylp.pdb',
#  'Repeat-6)-a-D-Glcp-(1-4)-b-D-GlcpA-(1-4)-b-D-GalpNAc3Ac-(1-3)-a-D-Galp-(1-3)-b-D-GalpNAc-(1-.pdb',
#  'DB26379.pdb',
#  'DB26961.pdb',
#  'DB26405.pdb',
#  'DB22529.pdb',
#  'DB26879.csv',
#  'DB26715.pdb',
#  'DB8939.pdb',
#  'a-L-Fucp-(1-2)-a-D-Galp.csv',
#  'DB22485.csv',
#  'a-d-manp.pdb',
#  'a-L-Fucp-(1-3)-b-D-Glcp1OMe.csv',
#  'Repeat-4)-a-D-GlcpA-(1-3)-a-D-Glcp-(1-3)-b-D-ManpNAc-(1-4)-b-D-Glcp-(1-4)-a-D-GlcpNAc-(1-.pdb',
#  'DB26502.pdb',
#  'DB22544.csv',
#  'b-D-GlcpNAc-(1-2)-b-D-GalpA-(1-3)-a-D-GalpNAc-(1-4)-a-D-GalpA.pdb',
#  'b-D-GalpA.pdb',
#  'DB26383.csv',
#  'a-L-Fucp-(1-2)-b-D-Manp.pdb',
#  'b-D-Glcp-(1-4)-b-D-GlcpA-(1-3)-a-D-GalpA2SO3-(1-4)-b-D-Galp.pdb',
#  'a-D-Glcp-(1-2)-b-D-Galp-(1-4)-a-D-GlcpNAc-(1-4)-b-D-Glcp-(1-3)-b-D-GlcpNAc.pdb',
#  'DB26716.pdb',
#  'b-D-Galp-(1-3)-b-D-Glcp-(1-3)-b-D-Xylp-(1-4)-b-D-Xylp-(1-4)-b-L-Galp-(2-1)-b-D-Xylp.csv',
#  'a-L-Rhap-(1-3)-b-D-Glcp1OMe.csv',
#  'Repeat-4)-a-D-GlcpNAc-(1-4)-a-D-GlcpA-(1-3)-a-D-Galp-(1-3)-b-D-ManpNAc-(1-4)-b-D-Glcp-(1-.pdb',
#  'b-D-Ribf-(1-4)-b-D-Galp-(1-3)-a-D-GlcpNac-(1-4)-a-D-GalpA.csv',
#  'DB26910.csv',
#  'a-D-Manp-(1-2)-b-D-Glcp1OMe.pdb',
#  'b-D-Galp-(1-3)-b-D-GlcpNAc.csv',
#  'b-D-Glcp-(1-4)-b-D-Glcp.pdb',
#  'b-D-Xylp-(1-3)-b-L-Arap.csv',
#  'b-D-GlcpNAc-(1-4)-b-D-GlcpNAc.pdb',
#  'DB22552.pdb',
#  'DB27270.pdb',
#  'b-D-Kdop-(2-3)-b-D-Galp-(1-4)-a-D-Galp-(1-3)-b-D-Galp.pdb',
#  'DB26813.pdb',
#  'a-L-Rhap-(1-3)-b-D-GlcpNAc.pdb',
#  'DB9919.csv',
#  'b-D-Galp-(1-3)-b-D-Glcp-(1-3)-b-D-Xylp-(1-4)-b-D-Xylp-(1-4)-a-L-Galp-(2-1)-b-D-Xylp.pdb',
#  'DB26403.csv',
#  'DB27099.csv',
#  'b-D-Xylp.pdb',
#  'b-L-Fucp-(1-3)-b-D-Glcp1OMe.csv',
#  'a-D-Quip4N-(1-4)-a-D-GlcpA-(1-6)-a-D-GlcpNAc-(1-4)-a-L-GulpA-(1-3)-a-D-FucpNAc.csv',
#  'a-D-Idop.pdb',
#  'a-L-Rhap-(1-3)-b-D-Galp-(1-4)-b-D-GalpNAc-(3-1)-b-D-Galp.csv',
#  'b-D-ManpNAc.csv']
