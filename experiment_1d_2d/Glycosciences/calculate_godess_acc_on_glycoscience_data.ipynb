# %%
import pandas as pd 
import numpy as np
import os

# %%
glycoscience_data = os.listdir('glycoscience/')

g = glycoscience_data[0]
# Out:
# 'DB22549.csv'

# %%
with open('Linear/Conversion-Glycosciences.txt') as f:
    f = f.readlines()

for i in range(len(f)):
    temp_g = f[i]
    temp_g = temp_g.replace('\n', '')
    temp_g = temp_g + '.csv'
    
    if temp_g in glycoscience_data:
        temp_glcosci = pd.read_csv('glycoscience/' + temp_g)
        
        path_godess =

# %%
temp_glcosci
# Out:
#        Residual Connection Atom   Shift  Residual Num
# 0   B-D-GLCPNAC              H1    4.67             1
# 1   B-D-GLCPNAC              H2    3.64             1
# 2   B-D-GLCPNAC              H3    3.48             1
# 3   B-D-GLCPNAC              H4    3.36             1
# 4   B-D-GLCPNAC              H5    3.29             1
# 5   B-D-GLCPNAC              H6    3.78             1
# 6   B-D-GLCPNAC             NAc    1.91             1
# 7      A-L-RHAP          3   H1    4.73             2
# 8      A-L-RHAP          3   H2    3.87             2
# 9      A-L-RHAP          3   H3    3.65             2
# 10     A-L-RHAP          3   H4    3.35             2
# 11     A-L-RHAP          3   H5    3.87             2
# 12     A-L-RHAP          3   H6    1.10             2
# 13  B-D-GLCPNAC              C1  102.40             1
# 14  B-D-GLCPNAC              C2   57.50             1
# 15  B-D-GLCPNAC              C3   74.90             1
# ...
